# %% [markdown]
# <a href="https://colab.research.google.com/github/dldkfma9577/githubtest/blob/main/7%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 마지막만 출력 나옴.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 64, input_shape = (28,28), return_sequences=False))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 64)                5952
# _________________________________________________________________
# dense (Dense)                (None, 10)                650
# =================================================================
# Total params: 6,602
# Trainable params: 6,602
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5145 - accuracy: 0.8403
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2702 - accuracy: 0.9206
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2269 - accuracy: 0.9344
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2123 - accuracy: 0.9395
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1924 - accuracy: 0.9454
#
# =============test result====================
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2049 - accuracy: 0.9407
#
#  Accuracy: 0.9407
# ==============================================

# %% [markdown]
# unit24개로 - 연습문제 1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 24, input_shape = (28,28), return_sequences=False))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 24)                1272
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                250
# =================================================================
# Total params: 1,522
# Trainable params: 1,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.1023 - accuracy: 0.6421
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6350 - accuracy: 0.8038
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5175 - accuracy: 0.8422
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4675 - accuracy: 0.8588
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4350 - accuracy: 0.8697
#
# =============test result====================
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4092 - accuracy: 0.8795
#
#  Accuracy: 0.8795
# ==============================================

# %% [markdown]
# unit 32개로  - 연습문제 1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 32, input_shape = (28,28), return_sequences=False))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_3 (SimpleRNN)     (None, 32)                1952
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                330
# =================================================================
# Total params: 2,282
# Trainable params: 2,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8930 - accuracy: 0.7008
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5269 - accuracy: 0.8175
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4265 - accuracy: 0.8654
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3455 - accuracy: 0.8995
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3114 - accuracy: 0.9098
#
# =============test result====================
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2679 - accuracy: 0.9238
#
#  Accuracy: 0.9238
# ==============================================

# %% [markdown]
# 128개  - 연습문제 1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 128, input_shape = (28,28), return_sequences=False))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_4 (SimpleRNN)     (None, 128)               20096
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 21,386
# Trainable params: 21,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3537 - accuracy: 0.8922
# Epoch 2/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1920 - accuracy: 0.9437
# Epoch 3/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1686 - accuracy: 0.9516
# Epoch 4/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1582 - accuracy: 0.9543
# Epoch 5/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1402 - accuracy: 0.9597
#
# =============test result====================
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1124 - accuracy: 0.9677
#
#  Accuracy: 0.9677
# ==============================================

# %% [markdown]
# 2개 layer - 연습문제 1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 128, input_shape = (28,28), return_sequences=False))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_5 (SimpleRNN)     (None, 128)               20096
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                330
# =================================================================
# Total params: 24,554
# Trainable params: 24,554
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3680 - accuracy: 0.8883
# Epoch 2/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1886 - accuracy: 0.9451
# Epoch 3/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1632 - accuracy: 0.9526
# Epoch 4/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1518 - accuracy: 0.9568
# Epoch 5/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1439 - accuracy: 0.9585
#
# =============test result====================
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1249 - accuracy: 0.9606
#
#  Accuracy: 0.9606
# ==============================================

# %% [markdown]
# **어떤 모델, 최적화 함수, 러닝레이트 미리 정리해오기**

# %% [markdown]
# 전부 출력 나옴

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 64,return_sequences=True, input_shape=(28,28)))
model.add(tf.keras.layers.Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_3 (SimpleRNN)     (None, 28, 64)            5952
# _________________________________________________________________
# flatten (Flatten)            (None, 1792)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                57376
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 63,658
# Trainable params: 63,658
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2447 - accuracy: 0.9257
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1186 - accuracy: 0.9645
# Epoch 3/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0924 - accuracy: 0.9723
# Epoch 4/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0766 - accuracy: 0.9764
# Epoch 5/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0678 - accuracy: 0.9786
#
# =============test result====================
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0771 - accuracy: 0.9768
#
#  Accuracy: 0.9768
# ==============================================

# %% [markdown]
# 심층 RNN - 2개의 은닉층

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 64,return_sequences=True, input_shape=(28,28)))
model.add(SimpleRNN(units = 32))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_4 (SimpleRNN)     (None, 28, 64)            5952
# _________________________________________________________________
# simple_rnn_5 (SimpleRNN)     (None, 32)                3104
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 9,386
# Trainable params: 9,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.5211 - accuracy: 0.8382
# Epoch 2/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2490 - accuracy: 0.9272
# Epoch 3/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2039 - accuracy: 0.9414
# Epoch 4/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1828 - accuracy: 0.9481
# Epoch 5/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1656 - accuracy: 0.9516
#
# =============test result====================
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1617 - accuracy: 0.9524
#
#  Accuracy: 0.9524
# ==============================================

# %% [markdown]
# 심층RNN - 3개의 은닉층 - 연습문제 2

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense, Flatten
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = Sequential()
model.add(SimpleRNN(units = 64,return_sequences=True, input_shape=(28,28)))
model.add(SimpleRNN(units = 64,return_sequences=True))
model.add(SimpleRNN(units = 32,return_sequences=True))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_9 (SimpleRNN)     (None, 28, 64)            5952
# _________________________________________________________________
# simple_rnn_10 (SimpleRNN)    (None, 28, 64)            8256
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 28, 32)            3104
# _________________________________________________________________
# flatten (Flatten)            (None, 896)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                28704
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                330
# =================================================================
# Total params: 46,346
# Trainable params: 46,346
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2294 - accuracy: 0.9307
# Epoch 2/5
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1034 - accuracy: 0.9683
# Epoch 3/5
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0825 - accuracy: 0.9742
# Epoch 4/5
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0697 - accuracy: 0.9778
# Epoch 5/5
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0616 - accuracy: 0.9799
#
# =============test result====================
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0879 - accuracy: 0.9740
#
#  Accuracy: 0.9740
# ==============================================
