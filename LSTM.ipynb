# %% [markdown]
# <a href="https://colab.research.google.com/github/dldkfma9577/githubtest/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LSTM 구현**
#
# 1.   test : loss: 0.0581 - accuracy: 0.9812
# 2.   learning : loss: 0.0573 - accuracy: 0.9825

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense, Flatten
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(units = 64, input_shape =(28,28)))
model.add(tf.keras.layers.Dense(10,activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 64)                23808
# _________________________________________________________________
# dense (Dense)                (None, 10)                650
# =================================================================
# Total params: 24,458
# Trainable params: 24,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4195 - accuracy: 0.8676
# Epoch 2/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.1348 - accuracy: 0.9594
# Epoch 3/5
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.0920 - accuracy: 0.9719
# Epoch 4/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0710 - accuracy: 0.9786
# Epoch 5/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0573 - accuracy: 0.9825
#
# =============test result====================
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0581 - accuracy: 0.9812
#
#  Accuracy: 0.9812
# ==============================================

# %% [markdown]
# **LSTM 구현 - return true**
#
# 1.   test : loss: 0.0566 - accuracy: 0.9812
# 2.   learning : loss: 0.0355 - accuracy: 0.9889

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense, Flatten
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(units = 64, return_sequences = True, input_shape =(28,28)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(10,activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 28, 64)            23808
# _________________________________________________________________
# flatten (Flatten)            (None, 1792)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                17930
# =================================================================
# Total params: 41,738
# Trainable params: 41,738
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2299 - accuracy: 0.9317
# Epoch 2/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0782 - accuracy: 0.9760
# Epoch 3/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0552 - accuracy: 0.9830
# Epoch 4/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0444 - accuracy: 0.9860
# Epoch 5/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0355 - accuracy: 0.9889
#
# =============test result====================
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0566 - accuracy: 0.9812
#
#  Accuracy: 0.9812
# ==============================================

# %% [markdown]
# **GRU 구현**
#
# 1.   test :  loss: 0.0603 - accuracy: 0.9827
# 2.   learning : loss: 0.0624 - accuracy: 0.9808

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense, Flatten
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.GRU(units=64, input_shape = (28,28)))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 64)                18048
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 18,698
# Trainable params: 18,698
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.4465 - accuracy: 0.8540
# Epoch 2/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1361 - accuracy: 0.9592
# Epoch 3/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0940 - accuracy: 0.9718
# Epoch 4/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0737 - accuracy: 0.9775
# Epoch 5/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0624 - accuracy: 0.9808
#
# =============test result====================
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0603 - accuracy: 0.9827
#
#  Accuracy: 0.9827
# ==============================================

# %% [markdown]
# **양방향 - RNN**
#
# 1.   test : loss: 0.0957 - accuracy: 0.9748
# 2.   learning :loss: 0.0860 - accuracy: 0.9769

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense, Flatten, Bidirectional
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = tf.keras.models.Sequential()
model.add(Bidirectional(SimpleRNN(units=64, return_sequences=True),input_shape = (28,28)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(10,activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 28, 128)           11904
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3584)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                35850
# =================================================================
# Total params: 47,754
# Trainable params: 47,754
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2335 - accuracy: 0.9291
# Epoch 2/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1264 - accuracy: 0.9635
# Epoch 3/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1048 - accuracy: 0.9705
# Epoch 4/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0919 - accuracy: 0.9748
# Epoch 5/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0860 - accuracy: 0.9769
#
# =============test result====================
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0957 - accuracy: 0.9748
#
#  Accuracy: 0.9748
# ==============================================

# %% [markdown]
# **양방향 - LSTM**
#
# 1.   test : loss: 0.0457 - accuracy: 0.9863
# 2.   learning :loss: 0.0347 - accuracy: 0.9891

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense, Flatten, LSTM
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = tf.keras.models.Sequential()
model.add(Bidirectional(LSTM(units=64, return_sequences = True), input_shape=(28,28)))
model.add(Flatten())
model.add(Dense(10,activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 28, 128)           47616
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3584)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                35850
# =================================================================
# Total params: 83,466
# Trainable params: 83,466
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.2086 - accuracy: 0.9355
# Epoch 2/5
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0745 - accuracy: 0.9772
# Epoch 3/5
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0526 - accuracy: 0.9838
# Epoch 4/5
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0413 - accuracy: 0.9870
# Epoch 5/5
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0347 - accuracy: 0.9891
#
# =============test result====================
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0457 - accuracy: 0.9863
#
#  Accuracy: 0.9863
# ==============================================

# %% [markdown]
# **양방향 - Deep Bidirectional LSTM**
#
# 1.   test :
# 2.   learning :

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import SimpleRNN,Dense, Flatten, LSTM
from tensorflow.keras.optimizers import Adam

#MNIST 데이터 로드
(train_images, train_labels),(test_images, test_labels) = load_data()

#픽셀 값 0-1로 정규화
train_images, test_images = train_images / 255.0, test_images / 255.0

#데이터 레이블 one hot 코드 변경
one_hot_train_labels = to_categorical(train_labels,10)
one_hot_test_labels = to_categorical(test_labels, 10)

#모델 구성
model = tf.keras.models.Sequential()
model.add(Bidirectional(LSTM(units=64, return_sequences = True), input_shape=(28,28)))
model.add(Bidirectional(LSTM(units=64, return_sequences = True)))
model.add(Bidirectional(LSTM(units=64, return_sequences = True)))
model.add(Flatten())
model.add(Dense(10,activation='softmax'))

#모델 학습을 위한 최적화 함수 및 손실 함수 등 설정
model.compile(optimizer = Adam(learning_rate=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])

#모델 구조 출력
model.summary()

#모델 학습 수행
history = model.fit(train_images,one_hot_train_labels,epochs = 5,batch_size= 32)

#모델 평가
print("\n=============test result====================")
labels = model.predict(test_images)
print("\n Accuracy: %.4f" % (model.evaluate(test_images, one_hot_test_labels)[1]))

#결과 이미지로 출력
fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2,5,i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %np.argmax(labels[i]))
  subplot.imshow(test_images[i], cmap = plt.cm.gray_r)
plt.show()

print("==============================================")
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 28, 128)           47616
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 28, 128)           98816
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 28, 128)           98816
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3584)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                35850
# =================================================================
# Total params: 281,098
# Trainable params: 281,098
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 141s 75ms/step - loss: 0.2072 - accuracy: 0.9329
# Epoch 2/5
# 1875/1875 [==============================] - 141s 75ms/step - loss: 0.0710 - accuracy: 0.9776
# Epoch 3/5
#  501/1875 [=======>......................] - ETA: 1:44 - loss: 0.0489 - accuracy: 0.9843
